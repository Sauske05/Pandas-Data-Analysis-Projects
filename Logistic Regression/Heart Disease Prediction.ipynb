# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("./Heart_Disease_Prediction.csv")
df
# Out:
#      Age  Sex  Chest pain type   BP  ...  Slope of ST  Number of vessels fluro  Thallium  Heart Disease
# 0     70    1                4  130  ...            2                        3         3       Presence
# 1     67    0                3  115  ...            2                        0         7        Absence
# 2     57    1                2  124  ...            1                        0         7       Presence
# 3     64    1                4  128  ...            2                        1         7        Absence
# 4     74    0                2  120  ...            1                        1         3        Absence
# ..   ...  ...              ...  ...  ...          ...                      ...       ...            ...
# 265   52    1                3  172  ...            1                        0         7        Absence
# 266   44    1                2  120  ...            1                        0         7        Absence
# ...

# %%
null_count = df.isna().sum()
null_count
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
df.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease               object
# dtype: object

# %%
test_column = set(df['Number of vessels fluro'])
test_column
# Out:
# {0, 1, 2, 3}

# %%
column_list =  list(df.columns)
column_list
# Out:
# ['Age',
#  'Sex',
#  'Chest pain type',
#  'BP',
#  'Cholesterol',
#  'FBS over 120',
#  'EKG results',
#  'Max HR',
#  'Exercise angina',
#  'ST depression',
#  'Slope of ST',
#  'Number of vessels fluro',
#  'Thallium',
#  'Heart Disease']

# %%
plt.figure(figsize= (10,15))
plot_number = 1
for i in range(0, len(column_list)) :
    plt.subplot(7, 2 , plot_number)
    plot_number = plot_number + 1
    sns.histplot(data=df, x=column_list[i])
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize= (10,15))
plot_number = 1
for i in range(0, len(column_list)) :
    if column_list[i] != 'Heart Disease':
        plt.subplot(7, 2 , plot_number)
        sns.boxplot(data=df, x=column_list[i], y='Heart Disease')
    plot_number = plot_number + 1
plt.tight_layout()
plt.show()

# %%
import sklearn
x=df[column_list[:13]]
y=df['Heart Disease']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=5)

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg.fit(x_train,y_train)
y_pred=logreg.predict(x_test)
# Out:
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
sklearn.metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.8333333333333334

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
conf_matrix=pd.DataFrame(data=cm,columns=['Predicted:0','Predicted:1'],index=['Actual:0','Actual:1'])
plt.figure(figsize = (8,5))
sns.heatmap(conf_matrix, annot=True,fmt='d',cmap="YlGnBu")
# Out:
# <AxesSubplot:>
