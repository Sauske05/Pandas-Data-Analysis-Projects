# %%
import pandas as pd
import numpy as np
df = pd.read_csv('IMDB Top 250 Movies.csv')
df
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
df.columns
# Out:
# Index(['rank', 'name', 'year', 'rating', 'genre', 'certificate', 'run_time',
#        'tagline', 'budget', 'box_office', 'casts', 'directors', 'writers'],
#       dtype='object')

# %%
df = df[['rank', 'name', 'year', 'rating', 'genre',
#                 'certificate',
                'run_time',
#        'tagline',
                'budget', 'box_office',
#                 'casts', 'directors', 'writers'
               ]]

# %%
df
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
df = df.rename(columns= {'name' : 'Name', 'rank' : 'Rank', 'year' : 'Year', 'rating' : 'Rating', 'genre' : 'Genre', 'budget' : 'Budget', 'run_time' : 'Run_time', 'box_office' : 'Box_office'})

# %%
df
# Out:
#      Rank                      Name  Year  Rating                       Genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
 df.isna().sum()
# Out:
# Rank          0
# Name          0
# Year          0
# Rating        0
# Genre         0
# Run_time      0
# Budget        0
# Box_office    0
# dtype: int64

# %%
df = df.replace('Not Available', np.nan).dropna()
df
# Out:
#      Rank                      Name  Year  Rating                       Genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 244   245            The Iron Giant  1999     8.1  Animation,Action,Adventure
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
df.dtypes
# Out:
# Rank            int64
# Name           object
# Year            int64
# Rating        float64
# Genre          object
# Run_time       object
# Budget         object
# Box_office     object
# dtype: object

# %%
df['Budget'] = df['Budget'].str.replace(r'[^0-9]', '')
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12996\3282921392.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Budget'] = df['Budget'].str.replace(r'[^0-9]', '')
#      Rank                      Name  Year  Rating                       Genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 244   245            The Iron Giant  1999     8.1  Animation,Action,Adventure
# 245   246                  The Help  2011     8.1                       Drama
# ...

# %%
df['Budget'] = pd.to_numeric(df['Budget'])
df.dtypes
# Out:
# Rank            int64
# Name           object
# Year            int64
# Rating        float64
# Genre          object
# Run_time       object
# Budget          int64
# Box_office     object
# dtype: object

# %%
df['Box_office'] = pd.to_numeric(df['Box_office'])

# %%
df['Box_office'] = df['Box_office'].str.replace(r'[^0-9]', '')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12996\4292453588.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Box_office'] = df['Box_office'].str.replace(r'[^0-9]', '')

# %%
df
# Out:
#      Rank                      Name  Year  Rating                       Genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 244   245            The Iron Giant  1999     8.1  Animation,Action,Adventure
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
df = df.sort_values(by=['Box_office'], ascending=False)
df['Profit'] = df['Box_office'] - df['Budget']
df = df.reset_index(drop= True)
df
# Out:
#      Rank                                          Name  Year  Rating  \
# 0      78                             Avengers: Endgame  2019     8.4
# 1      63                        Avengers: Infinity War  2018     8.4
# 2     150                       Spider-Man: No Way Home  2021     8.2
# 3     106                             Top Gun: Maverick  2022     8.3
# 4     181  Harry Potter and the Deathly Hallows: Part 2  2011     8.1
# ..    ...                                           ...   ...     ...
# 205   242                         It Happened One Night  1934     8.1
# 206    64                   Witness for the Prosecution  1957     8.4
# 207    60                                Paths of Glory  1957     8.4
# 208     5                                  12 Angry Men  1957     9.0
# 209   238                                Cool Hand Luke  1967     8.1
#
#                         Genre Run_time     Budget  Box_office      Profit
# ...

# %%
groupby = df.groupby(['Genre']).mean()
groupby.sort_values('Rating', ascending= False)
# Out:
#                            Rank    Year  Rating       Budget    Box_office  \
# Genre
# Adventure,Western          10.0  1966.0     8.8    1200000.0  2.525389e+07
# Action,Adventure,Drama     28.8  2005.0     8.7  148000000.0  1.259042e+09
# Crime,Drama,Fantasy        27.0  1999.0     8.6   60000000.0  2.868014e+08
# Drama,Family,Fantasy       21.0  1946.0     8.6    3180000.0  8.574081e+06
# Adventure,Drama,Sci-Fi     25.0  2014.0     8.6  165000000.0  7.738672e+08
# ...                         ...     ...     ...          ...           ...
# Adventure,Family,Fantasy  201.5  1975.0     8.1   63888500.0  6.839988e+08
# Adventure,Thriller        204.0  1975.0     8.1    7000000.0  4.765121e+08
# Animation,Comedy,Drama    200.0  2009.0     8.1    8240000.0  1.740429e+06
# Drama,Fantasy             199.0  1957.0     8.1     150000.0  3.112120e+05
# Comedy                    244.0  1979.0     8.0    4000000.0  2.074573e+07
#
#                                 Profit
# Genre
# ...

# %%
import seaborn as sns
sns.set_theme()
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
